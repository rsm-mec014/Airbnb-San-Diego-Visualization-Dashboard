# %%
import pandas as pd
from pandas import json_normalize 
import geopandas

# %%
listings = pd.read_csv('data/listings.csv.gz', compression='gzip')
listings_name = listings['name'].str.split(' · ',expand=True)
listings = pd.concat((listings, listings_name), axis=1).drop(columns='name')
listings.rename(columns={0: 'name', 1:'stars', 2: 'bedrooms', 3:'bedrooms', 4: 'baths'}, inplace=True)

listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0      6      https://www.airbnb.com/rooms/6  20230918050343   2023-09-18
# 1  29967  https://www.airbnb.com/rooms/29967  20230918050343   2023-09-18
# 2  54001  https://www.airbnb.com/rooms/54001  20230918050343   2023-09-18
# 3  62274  https://www.airbnb.com/rooms/62274  20230918050343   2023-09-18
# 4  75668  https://www.airbnb.com/rooms/75668  20230918050343   2023-09-18
#
#             source                                        description  \
# 0  previous scrape  You read that right, this craftsman home was t...
# 1      city scrape  This 2 bedroom, 2 full bathroom home offers al...
# 2      city scrape  Off the beaten path:  4 garden areas,  2 garde...
# 3      city scrape  Modern, cozy, artsy, and european in a lush ga...
# 4      city scrape  <b>The space</b><br />Medium large bedroom wit...
#
#                                neighborhood_overview  \
# ...

# %%
listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  1.249700e+04  1.249700e+04  1.249700e+04         12494.000000
# mean   3.419451e+17  2.023092e+13  1.587920e+08            63.193213
# std    3.969575e+17  0.000000e+00  1.663001e+08           307.889957
# min    6.000000e+00  2.023092e+13  2.900000e+01             1.000000
# 25%    3.022818e+07  2.023092e+13  2.395070e+07             1.000000
# 50%    5.167000e+07  2.023092e+13  8.609956e+07             4.000000
# 75%    7.589667e+17  2.023092e+13  2.721912e+08            18.000000
# max    9.827952e+17  2.023092e+13  5.370021e+08          4586.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               12494.000000                           0.0  12497.000000
# mean                  102.250280                           NaN     32.770201
# std                   474.152803                           NaN      0.065866
# ...

# %% [markdown]
# **Possible tasks**: Analyze trend.
#
#
# Predict price based on different parameters. (refer for landlord)
#
# Use past data (YoY)

# %%
reviews = pd.read_csv('data/reviews.csv.gz',compression='gzip')
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0           6        8  2008-06-22          415      Terrence
# 1           6     4383  2009-06-22         3762     Christine
# 2           6  1722383  2012-07-16      1864778          Hieu
# 3           6  5595071  2013-07-07       117966         Maria
# 4           6  5631156  2013-07-08      6563815        Mathew
#
#                                             comments
# 0  Sara is an awesome hostess.  She was very cons...
# 1  My stay at “Craftsmen” was wonderful!  Sara wa...
# 2  This was my first time using Airbnb and Sara m...
# 3  Sara was a very pleasant host! Reservation was...
# 4  Sara was such an amazing hostess! My girlfrien...

# %% [markdown]
# **Customer dashboard**: bag of word, word cloud to analyze customer satisfactions.
#
# Comment summary for customer's reference. Create a view.
#
# 1. Summarize keyword (top 6 keywords) -- Word dictionary for sentiment category
#
# 2. Visualize scores (checkin, cleaness)
#
# 3. Show picture

# %%
neighbourhoods = pd.read_csv('data/neighbourhoods.csv')
neighbourhoods.head()
# Out:
#    neighbourhood_group                neighbourhood
# 0                  NaN               Allied Gardens
# 1                  NaN                   Alta Vista
# 2                  NaN  Amphitheater And Water Park
# 3                  NaN                  Balboa Park
# 4                  NaN                  Bario Logan

# %%
geo = geopandas.read_file("data/neighbourhoods.geojson")
geo.head()
# Out:
#                  neighbourhood  neighbourhood_group  \
# 0  Amphitheater And Water Park                  NaN
# 1                   Bella Lago                  NaN
# 2           Bonita Long Canyon                  NaN
# 3                    East Lake                  NaN
# 4              Eastlake Trails                  NaN
#
#                                             geometry
# 0  MULTIPOLYGON (((-117.01452 32.58790, -117.0144...
# 1  MULTIPOLYGON (((-116.94128 32.68431, -116.9412...
# 2  MULTIPOLYGON (((-117.01149 32.66353, -117.0114...
# 3  MULTIPOLYGON (((-116.99302 32.66040, -116.9816...
# 4  MULTIPOLYGON (((-116.95512 32.64124, -116.9550...

# %% [markdown]
# **Possible tasks**

# %%
calendar = pd.read_csv('data/calendar.csv.gz',compression='gzip')
calendar[calendar['listing_id']==29967]#['price'].value_counts()
# Out:
#      listing_id        date available    price adjusted_price  minimum_nights  \
# 365       29967  2023-09-18         t  $225.00        $225.00               4
# 366       29967  2023-09-19         t  $225.00        $225.00               4
# 367       29967  2023-09-20         f  $225.00        $225.00               4
# 368       29967  2023-09-21         f  $225.00        $225.00               4
# 369       29967  2023-09-22         f  $225.00        $225.00               4
# ..          ...         ...       ...      ...            ...             ...
# 725       29967  2024-09-12         t  $225.00        $225.00               4
# 726       29967  2024-09-13         t  $225.00        $225.00               4
# 727       29967  2024-09-14         t  $225.00        $225.00               4
# 728       29967  2024-09-15         t  $225.00        $225.00               4
# 729       29967  2024-09-16         t  $225.00        $225.00               4
#
#      maximum_nights
# ...

# %% [markdown]
# **Landlord**:
#
# 1. Show predicted price
#
# 2. Show influential factors to price. Suggestions for landlord.

# %% [markdown]
# **Map**:
#
# 1. Heatmap of scores, price.
#
# 2. Distance, density
#
# 3. Filter: number of houses

# %% [markdown]
# Package: dash component
